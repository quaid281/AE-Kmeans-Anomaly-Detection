# %%
import os
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import f1_score, silhouette_score, silhouette_samples
from scipy.spatial.distance import cosine
from scipy.cluster.vq import kmeans, vq

from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_predict, train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Input, LSTM, BatchNormalization, Dropout, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13056855464854918628
# xla_global_id: -1
# ]

# %%
# Create relative path method to access all the files in data/raw/train folder
def relative_path(path):
    return os.path.join(os.getcwd(), path)

# %%
def evaluate(final_df, stream,final_predictions):
    # Calculate F1 Score
    f1 = f1_score(final_df['actual_anomaly'], final_df['predicted_labels'])
    print(f"F1 Score: {f1}")
    # True Positives
    tp_filter = (final_df['actual_anomaly'] == 1) & (final_df['predicted_labels'] == 1)
    # True Negatives
    tn_filter = (final_df['actual_anomaly'] == 0) & (final_df['predicted_labels'] == 0)
    # False Positives
    fp_filter = (final_df['actual_anomaly'] == 0) & (final_df['predicted_labels'] == 1)
    # False Negatives
    fn_filter = (final_df['actual_anomaly'] == 1) & (final_df['predicted_labels'] == 0)
    # Precision
    precision = len(final_df[tp_filter]) / (len(final_df[tp_filter]) + len(final_df[fp_filter]))
    # Recall
    recall = len(final_df[tp_filter]) / (len(final_df[tp_filter]) + len(final_df[fn_filter]))
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f'False Negatives: {len(final_df[fn_filter])}')
    print(f'False Positives: {len(final_df[fp_filter])}')
    print(f'True Negatives: {len(final_df[tn_filter])}')
    print(f'True Positives: {len(final_df[tp_filter])}')
    
    # Add evaluation Metrics to .csv file for on sample where chan_id == stream
    final_predictions.loc[final_predictions['chan_id'] == stream, 'f1'] = f1
    final_predictions.loc[final_predictions['chan_id'] == stream, 'precision'] = precision
    final_predictions.loc[final_predictions['chan_id'] == stream, 'recall'] = recall
    final_predictions.loc[final_predictions['chan_id'] == stream, 'tp'] = len(final_df[tp_filter])
    final_predictions.loc[final_predictions['chan_id'] == stream, 'tn'] = len(final_df[tn_filter])
    final_predictions.loc[final_predictions['chan_id'] == stream, 'fp'] = len(final_df[fp_filter])
    final_predictions.loc[final_predictions['chan_id'] == stream, 'fn'] = len(final_df[fn_filter])
    
    # calculate range or sequence of anomalies predicted
    predicted_anomalies = []
    start = 0
    end = 0
    while end < len(final_df):
        slice = final_df.iloc[start:end+1]
        if not slice.empty:
            if slice['predicted_labels'].iloc[0] == 1:
                if start == 0:
                    start = end
            else:
                if start != 0:
                    end = end - 1
                    predicted_anomalies.append([start,end])
                    start = 0
        if end < len(final_df):
            end += 1
    final_predictions.loc[final_predictions['chan_id'] == stream, 'predicted_anomalies'] = str(predicted_anomalies)
    return final_predictions

# %%
def train_autoencoder(train_df, test_df):
    # Split the data into train and test sets
    X_train, X_test = train_test_split(train_df.values, test_size=0.2, random_state=42)
    
    # Define the dimensions of the latent space
    latent_dim = 8
    input_dim = train_df.shape[1]
    
    # Create an autoencoder model with dropout layers
    # Do not use dropouts.  For some reason we can't build clusters when using dropout
    input_layer = keras.Input(shape=(train_df.shape[1],))
    encoded = layers.Dense(32, activation='relu')(input_layer)
    encoded = layers.Dense(16, activation='relu')(encoded)
    
    # Attention Mechanism
    # attention_probs = Dense(16, activation='softmax', name='attention_vec')(input_layer)  # Learn attention probabilities
    # attention_mul = Lambda(lambda x: x[0] * x[1], name='attention_mul')([encoded, attention_probs])
    
    # Latent layer with attention
    latent_layer = Dense(latent_dim, activation='relu')(encoded)
    

    # Decoder
    decoded = layers.Dense(16, activation='relu')(latent_layer)
    decoded = layers.Dense(32, activation='relu')(decoded)
    decoded = layers.Dense(input_dim, activation='sigmoid')(decoded)

    autoencoder = keras.Model(input_layer, decoded)

    # Compile the autoencoder with gradient clipping
    optimizer = Adam(clipnorm=1.0)  # Clip gradients by their norm
    autoencoder.compile(optimizer=optimizer, loss='mse')

    # Define Early Stopping and Reduce Learning Rate callbacks
    early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001, verbose=1)

    # Train the autoencoder with callbacks
    history = autoencoder.fit(
        X_train, X_train,
        epochs=300,
        batch_size=32,
        shuffle=True,
        validation_data=(X_test, X_test),  # Validation data for early stopping
        callbacks=[early_stopping, reduce_lr]  # Pass the callbacks
    )

    encoder = keras.Model(input_layer, encoded)
    # Encode entire dataset
    test_latent_representation = encoder.predict(test_df.values)
    train_latent_representation = encoder.predict(train_df.values)
    return test_latent_representation, train_latent_representation, autoencoder

# %%
def get_reconstruction_loss(autoencoder, test_df,final_df):
    max_window_size = 100
    recon_losses = []
    start = 0
    end = 0

    while end < len(test_df):
        slice = test_df.iloc[start:end+1]
        print(f"Processing slice: Start = {start}, End = {end}, Shape = {slice.shape}")

        # Check if the slice is empty
        if not slice.empty:
            # Reconstruct slice
            recon = autoencoder.predict(slice.values)
            print(f"Reconstructed shape: {recon.shape}")

            # Calculate recon loss for the entire slice
            loss = np.mean(np.square(slice.values - recon), axis=1)
            mean_loss = np.mean(loss)
            recon_losses.append(mean_loss)

        # Increment the start by 1 if the end is greater than or equal to the max window size
        if end >= max_window_size:
            start += 1

        # Check if end has reached the end of the DataFrame
        if end < len(test_df):
            end += 1
    final_df['recon_losses'] = recon_losses
    return final_df

# %%
def perform_kmeans_with_refinement(test_latent_representation, train_latent_representation, k_values, final_df, max_iter=400, random_state=42):
    """
    Perform K-Means clustering with iterative refinement based on silhouette score.

    Parameters:
    - X: Input data (features) as a DataFrame or numpy array.
    - k_values: List of K values to consider.
    - n_init: Number of times the K-Means algorithm will be run with different centroid seeds.
    - max_iter: Maximum number of iterations for each run of the K-Means algorithm.
    - random_state: Seed for randomization (optional).

    Returns:
    - Tuple containing (best_K, best_score, cluster_labels).
    """
    
    if isinstance(test_latent_representation, pd.DataFrame):
        test_latent_representation = test_latent_representation.values  # if dataframe Convert DataFrame to numpy array

    if isinstance(train_latent_representation, pd.DataFrame):
        train_latent_representation = train_latent_representation.values  # if dataframe Convert DataFrame to numpy array
    
    scaler = StandardScaler()
    train_latent_representation = scaler.fit_transform(train_latent_representation)
    test_latent_representation = scaler.transform(test_latent_representation)
    
    best_k = None
    best_silhouette_score = -1

    for k in k_values:
        print(f"Current k value: {k}")
        kmeans = KMeans(n_clusters=k, n_init=20, init='k-means++', max_iter=max_iter, random_state=random_state).fit(train_latent_representation)
        labels = kmeans.predict(train_latent_representation)

        # Calculate the silhouette score
        silhouette_values = silhouette_samples(train_latent_representation, labels, metric='euclidean')

        # Calculate the weighted average of the silhouette coefficients
        silhouette_avg = np.mean(silhouette_values)
        print(f"Silhouette score: {silhouette_avg}")

        # Check if this is the best silhouette score so far
        if silhouette_avg > best_silhouette_score:
            best_k = k
            best_silhouette_score = silhouette_avg

    
    print(f"Best K: {best_k}")
    print(f"Best Silhouette Score: {best_silhouette_score}")
    
    kmeans = KMeans(n_clusters=best_k, n_init=20, init='k-means++',max_iter=max_iter,random_state=random_state).fit(train_latent_representation)

    # Predicting the cluster labels for the test set
    cluster_labels = kmeans.predict(test_latent_representation)

    # Computing the distances of samples in test set to all cluster centers
    distances = kmeans.transform(test_latent_representation)

    # Extracting the distances of each sample to its assigned cluster
    distances_to_assigned_cluster = distances[np.arange(len(distances)), cluster_labels]
    cluster_centers = kmeans.cluster_centers_
    # Graph Cluster_centers
    plt.figure(figsize=(10, 6))
    plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], marker='x', s=100, c='r')
    plt.title('Cluster Centers')
    plt.xlabel('Feature 0')
    plt.ylabel('Feature 1')
    plt.show()
    final_df['anomaly_score'] = distances_to_assigned_cluster
    return final_df

# %%
import matplotlib.patches as patches

def perform_thresholding(final_df):
    X = final_df[['anomaly_score', 'recon_losses']].values

    # Separate the normal and anomalous points
    normal_points = X[final_df['actual_anomaly'] == 0]
    anomalous_points = X[final_df['actual_anomaly'] == 1]

    # Create separate scatter plots for the normal and anomalous points
    plt.scatter(normal_points[:, 0], normal_points[:, 1], c='blue', label='Normal')
    plt.scatter(anomalous_points[:, 0], anomalous_points[:, 1], c='red', label='Anomalous')

    plt.xlabel('Anomaly Score')
    plt.ylabel('Reconstruction Loss')

    nbrs = NearestNeighbors(n_neighbors=6000)
    nbrs.fit(X)
    distances, indices = nbrs.kneighbors(X)

    threshold = np.mean(distances)

    # Add a circle representing the decision boundary
    circle = patches.Circle((0, 0), threshold, fill=False, color='green')
    plt.gca().add_patch(circle)

    # Add a legend
    plt.legend()

    plt.show()

    predicted_labels = np.where(distances.mean(axis=1) > threshold, 1, 0)
    final_df['predicted_labels'] = predicted_labels

    return final_df

# %%
def distances_recon_concat_ground_truth(final_df, labeled_anomalies, stream):
    anomaly_sequences = labeled_anomalies[labeled_anomalies['chan_id'] == stream]['anomaly_sequences'].tolist()
    actual_anomalies = [eval(seq) for seq in anomaly_sequences]
    
    # Initialize a binary array with zeros
    binary_labels = np.zeros(final_df.shape[0])

    # Check if actual_anomalies is a nested list
    if len(actual_anomalies) == 1 and isinstance(actual_anomalies[0], list) and len(actual_anomalies[0]) == 1:
        # Handle nested structure
        anomaly_sequence = actual_anomalies[0][0]
        start, end = anomaly_sequence[0], anomaly_sequence[1]
        binary_labels[start:end + 1] = 1
    else:
        # Handle non-nested structure (single-index anomalies)
        for sequence in actual_anomalies:
            if isinstance(sequence, int):
                binary_labels[sequence] = 1
    binary_frame = pd.DataFrame(binary_labels, columns=['actual_anomaly'])
    
    # Concatenate the DataFrames
    final_df = pd.concat([final_df, binary_frame], axis=1)
    return final_df

# %%
parent_dir = os.path.dirname(os.getcwd())
channels_folder = os.path.join(parent_dir, 'data','raw','train')
channels = os.listdir(channels_folder)

labeled_anomalies_file = os.path.join(parent_dir, 'data','processed','labeled_anomalies.csv')
labeled_anomalies = pd.read_csv(labeled_anomalies_file)
channel = 'D-1.npy'

final_predictions = labeled_anomalies.copy()
# Add a columns for f1 score, precision, recall, tp, tn, fp, fn to final predictions dataframe
final_predictions['f1'] = 0
final_predictions['precision'] = 0
final_predictions['recall'] = 0
final_predictions['tp'] = 0
final_predictions['tn'] = 0
final_predictions['fp'] = 0
final_predictions['fn'] = 0
final_predictions['predicted_anomaly_sequences'] = 0
stream = channel[:-4]
final_df = pd.DataFrame()    
print(f'Currently working on {stream} Channel')

train_df = pd.DataFrame(np.load(os.path.join(parent_dir, 'data','raw','train',f'{channel}')))
test_df = pd.DataFrame(np.load(os.path.join(parent_dir, 'data','raw','test',f'{channel}')))
scaler = MinMaxScaler()

test_latent_representation, train_latent_representation, autoencoder = train_autoencoder(train_df, test_df)

# Perform K-Means clustering with iterative refinement based on silhouette score\
final_df  = perform_kmeans_with_refinement(test_latent_representation, train_latent_representation, range(3,60), final_df)
# Perform Sliding Window Autoencoder to get reconstruction loss
final_df  = get_reconstruction_loss(autoencoder, test_df,final_df)
final_df  = distances_recon_concat_ground_truth(final_df, labeled_anomalies, stream)
final_df  = perform_thresholding(final_df)
    
final_predictions = evaluate(final_df, stream, final_predictions)
# Out:
# Currently working on D-1 Channel
# Epoch 1/300
# 72/72 [==============================] - 2s 5ms/step - loss: 0.1973 - val_loss: 0.0590 - lr: 0.0010
# Epoch 2/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0459 - val_loss: 0.0468 - lr: 0.0010
# Epoch 3/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0378 - val_loss: 0.0339 - lr: 0.0010
# Epoch 4/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0303 - val_loss: 0.0310 - lr: 0.0010
# Epoch 5/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0288 - val_loss: 0.0300 - lr: 0.0010
# Epoch 6/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0283 - val_loss: 0.0295 - lr: 0.0010
# Epoch 7/300
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0279 - val_loss: 0.0291 - lr: 0.0010
# Epoch 8/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0276 - val_loss: 0.0287 - lr: 0.0010
# Epoch 9/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0273 - val_loss: 0.0281 - lr: 0.0010
# Epoch 10/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0269 - val_loss: 0.0275 - lr: 0.0010
# Epoch 11/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0264 - val_loss: 0.0271 - lr: 0.0010
# Epoch 12/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0262 - val_loss: 0.0270 - lr: 0.0010
# Epoch 13/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0260 - val_loss: 0.0268 - lr: 0.0010
# Epoch 14/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0260 - val_loss: 0.0267 - lr: 0.0010
# Epoch 15/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0259 - val_loss: 0.0265 - lr: 0.0010
# Epoch 16/300
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0258 - val_loss: 0.0264 - lr: 0.0010
# Epoch 17/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0257 - val_loss: 0.0262 - lr: 0.0010
# Epoch 18/300
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0256 - val_loss: 0.0262 - lr: 0.0010
# Epoch 19/300
# 72/72 [==============================] - 0s 4ms/step - loss: 0.
# Best Silhouette Score: 0.9878092408180237
# Processing slice: Start = 0, End = 0, Shape = (1, 25)
# 1/1 [==============================] - 0s 183ms/step
# Reconstructed shape: (1, 25)
# Processing slice: Start = 0, End = 1, Shape = (2, 25)
# 1/1 [==============================] - 0s 50ms/step
# Reconstructed shape: (2, 25)
# Processing slice: Start = 0, End = 2, Shape = (3, 25)
# 1/1 [==============================] - 0s 51ms/step
# Reconstructed shape: (3, 25)
# Processing slice: Start = 0, End = 3, Shape = (4, 25)
# 1/1 [==============================] - 0s 52ms/step
# Reconstructed shape: (4, 25)
# Processing slice: Start = 0, End = 4, Shape = (5, 25)
# 1/1 [==============================] - 0s 61ms/step
# Reconstructed shape: (5, 25)
# Processing slice: Start = 0, End = 5, Shape = (6, 25)
# 1/1 [==============================] - 0s 50ms/step
# Reconstructed shape: (6, 25)
# Processing slice: Start = 0, End = 6, Shape = (7, 25)
# 1/1 [==============================] - 0s 50ms/step
# Reconstructed shape: (7, 25)
# Processing slice: Start = 0, End = 7, Shape = (8, 25)
# 1/1 [==============================] - 0s 50ms/step
# Reconstructed shape: (8, 25)
# Processing slice: Start = 0, End = 8, Shape = (9, 25)
# 1/1 [==============================] - 0s 62ms/step
# Reconstructed shape: (9, 25)
# Processing slice: Start = 0, End = 9, Shape = (10, 25)
# 1/1 [==============================] - 0s 72ms/step
# Reconstructed shape: (10, 25)
# Processing slice: Start = 0, End = 10, Shape = (11, 25)
# 1/1 [==============================] - 0s 57ms/step
# Reconstructed shape: (11, 25)
# Processing slice: Start = 0, End = 11, Shape = (12, 25)
# 1/1 [==============================] - 0s 52ms/step
# Reconstructed shape: (12, 25)
# Processing slice: Start = 0, End = 12, Shape = (13, 25)
# 1/1 [==============================] - 0s 61ms/step
# Reconstructed shape: (13, 25)
# Processing slice: Start = 0, End = 13, Shape = (14, 25)
# 1/1 [==============================] - 0s 51ms/step
# Reconstructed shape: (14, 25)
# Processing slice: Start = 0, End = 14, Shape = (15, 25)
# 1/1 [==============================] - 0s 48ms/step
# Reconstructed shape: (15, 25)
# Processing slice: Start = 0, End = 15, Shape = (16, 25)
# 1/1 [==============================] - 0s 61ms/step
# Reconstructed shape: (16, 25)
# Processing slice: Start = 0, End = 16, Shape = (17, 25)
# 1/1 [==============================] - 0s 60ms/step
# Reconstructed shape: (17, 25)
# Processing slice: Start = 0, End = 17, Shape = (18, 25)
# 1/1 [==============================] - 0s 52ms/step
# Reconstructed shape: (18, 25)
# Processing slice: Start = 0, End = 18, Shape = (19, 25)
# 1/1 [==============================] - 0s 50ms/step
# Reconstructed shape: (19, 25)
# Processing slice: Start = 0, End = 19, Shape = (20, 25)
# 1/1 [==============================] - 0s 61ms/step
# Reconstructed shape: (20, 25)
# Processing slice: Start = 0, End = 20, Shape = (21, 25)
# 1/1 [==============================] - 0s 59ms/step
# Reconstructed shape: (21, 25)
# Processing slice: Start = 0, End = 21, Shape = (22, 25)
# 1/1 [==============================] - 0s 54ms/step
# Reconstructed shape: (22, 25)
# Processing slice: Start = 0, End = 22, Shape = (23, 25)
# 1/1 [==============================] - 0s 51ms/step
# Reconstructed shape: (23, 25)
# Processing slice: Start = 0, End = 23, Shape = (24, 25)
# 1/1 [==============================] - 0s 49ms/step
# Reconstructed shape: (24, 25)
# Processing slice: Start = 0, End = 24, Shape = (25, 25)
# 1/1 [==============================] - 0s 61ms/step
# Reconstructed shape: (25, 25)
# Processing slice: Start = 0, End = 25, Shape = (26, 25)
# 1/1 [==============================] - 0s 62ms/step
# Reconstructed shape: (26, 25)
# Processing slice: Start = 0, End = 26, Shape = (27, 25)
# 1/1 [==============================] - 0s 51ms/step
# Reconstructed shape: (27, 25)
# Processing slice: Start = 0, End = 27, Shape = (28, 25)
# 1/1 [==============================] - 0s 59ms/step
# Reconstructed shape: (28, 25)
# Processing slice: Start = 0, End = 28, Shape = (29, 25)
# 1/1 [==============================] - 0s 51ms/step
# Reconstructed shape: (29, 25)
# Processing slice: Start = 0, End = 29, Shape = (30, 25)
# 1/1 [==============================] - 0s 61ms/step
# Reconstructed shape: (30, 25)
# Processing slice: Start = 0, End = 30, Shape = (31, 25)
# 1/1 [==============================] - 0s 48ms/step
# Reconstructed shape: (31, 25)
# Processing slice: Start = 0, End = 31, Shape = (32, 25)
# 1/1 [==============================] - 0s 60ms/step
# Reconstructed shape: (32, 25)
# Processing slice: Start = 0, End = 32, Shape = (33, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (33, 25)
# Processing slice: Start = 0, End = 33, Shape = (34, 25)
# 2/2 [==============================] - 0s 9ms/step
# Reconstructed shape: (34, 25)
# Processing slice: Start = 0, End = 34, Shape = (35, 25)
# 2/2 [==============================] - 0s 11ms/step
# Reconstructed shape: (35, 25)
# Processing slice: Start = 0, End = 35, Shape = (36, 25)
# 2/2 [==============================] - 0s 7ms/step
# Reconstructed shape: (36, 25)
# Processing slice: Start = 0, End = 36, Shape = (37, 25)
# 2/2 [==============================] - 0s 9ms/step
# Reconstructed shape: (37, 25)
# Processing slice: Start = 0, End = 37, Shape = (38, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (38, 25)
# Processing slice: Start = 0, End = 38, Shape = (39, 25)
# 2/2 [==============================] - 0s 20ms/step
# Reconstructed shape: (39, 25)
# Processing slice: Start = 0, End = 39, Shape = (40, 25)
# 2/2 [==============================] - 0s 20ms/step
# Reconstructed shape: (40, 25)
# Processing slice: Start = 0, End = 40, Shape = (41, 25)
# 2/2 [==============================] - 0s 8ms/step
# Reconstructed shape: (41, 25)
# Processing slice: Start = 0, End = 41, Shape = (42, 25)
# 2/2 [==============================] - 0s 12ms/step
# Reconstructed shape: (42, 25)
# Processing slice: Start = 0, End = 42, Shape = (43, 25)
# 2/2 [==============================] - 0s 11ms/step
# Reconstructed shape: (43, 25)
# Processing slice: Start = 0, End = 43, Shape = (44, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (44, 25)
# Processing slice: Start = 0, End = 44, Shape = (45, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (45, 25)
# Processing slice: Start = 0, End = 45, Shape = (46, 25)
# 2/2 [==============================] - 0s 11ms/step
# Reconstructed shape: (46, 25)
# Processing slice: Start = 0, End = 46, Shape = (47, 25)
# 2/2 [==============================] - 0s 151ms/step
# Reconstructed shape: (47, 25)
# Processing slice: Start = 0, End = 47, Shape = (48, 25)
# 2/2 [==============================] - 0s 0s/step
# Reconstructed shape: (48, 25)
# Processing slice: Start = 0, End = 48, Shape = (49, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (49, 25)
# Processing slice: Start = 0, End = 49, Shape = (50, 25)
# 2/2 [==============================] - 0s 15ms/step
# Reconstructed shape: (50, 25)
# Processing slice: Start = 0, End = 50, Shape = (51, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (51, 25)
# Processing slice: Start = 0, End = 51, Shape = (52, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (52, 25)
# Processing slice: Start = 0, End = 52, Shape = (53, 25)
# 2/2 [==============================] - 0s 14ms/step
# Reconstructed shape: (53, 25)
# Processing slice: Start = 0, End = 53, Shape = (54, 25)
# 2/2 [==============================] - 0s 19ms/step
# Reconstructed shape: (54, 25)
# Processing slice: Start = 0, End = 54, Shape = (55, 25)
# 2/2 [==============================] - 0s 12ms/step
# Reconstructed shape: (55, 25)
# Processing slice: Start = 0, End = 55, Shape = (56, 25)
# 2/2 [==============================] - 0s 20ms/step
# Reconstructed shape: (56, 25)
# Processing slice: Start = 0, End = 56, Shape = (57, 25)
# 2/2 [==============================] - 0s 20ms/step
# Reconstructed shape: (57, 25)
# Processing slice: Start = 0, End = 57, Shape = (58, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (58, 25)
# Processing slice: Start = 0, End = 58, Shape = (59, 25)
# 2/2 [==============================] - 0s 13ms/step
# Reconstructed shape: (59, 25)
# Processing slice: Start = 0, End = 59, Shape = (60, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (60, 25)
# Processing slice: Start = 0, End = 60, Shape = (61, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (61, 25)
# Processing slice: Start = 0, End = 61, Shape = (62, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (62, 25)
# Processing slice: Start = 0, End = 62, Shape = (63, 25)
# 2/2 [==============================] - 0s 17ms/step
# Reconstructed shape: (63, 25)
# Processing slice: Start = 0, End = 63, Shape = (64, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (64, 25)
# Processing slice: Start = 0, End = 64, Shape = (65, 25)
# 3/3 [==============================] - 0s 8ms/step
# Reconstructed shape: (65, 25)
# Processing slice: Start = 0, End = 65, Shape = (66, 25)
# 3/3 [==============================] - 0s 10ms/step
# Reconstructed shape: (66, 25)
# Processing slice: Start = 0, End = 66, Shape = (67, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (67, 25)
# Processing slice: Start = 0, End = 67, Shape = (68, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (68, 25)
# Processing slice: Start = 0, End = 68, Shape = (69, 25)
# 3/3 [==============================] - 0s 9ms/step
# Reconstructed shape: (69, 25)
# Processing slice: Start = 0, End = 69, Shape = (70, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (70, 25)
# Processing slice: Start = 0, End = 70, Shape = (71, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (71, 25)
# Processing slice: Start = 0, End = 71, Shape = (72, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (72, 25)
# Processing slice: Start = 0, End = 72, Shape = (73, 25)
# 3/3 [==============================] - 0s 10ms/step
# Reconstructed shape: (73, 25)
# Processing slice: Start = 0, End = 73, Shape = (74, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (74, 25)
# Processing slice: Start = 0, End = 74, Shape = (75, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (75, 25)
# Processing slice: Start = 0, End = 75, Shape = (76, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (76, 25)
# Processing slice: Start = 0, End = 76, Shape = (77, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (77, 25)
# Processing slice: Start = 0, End = 77, Shape = (78, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (78, 25)
# Processing slice: Start = 0, End = 78, Shape = (79, 25)
# 3/3 [==============================] - 0s 10ms/step
# Reconstructed shape: (79, 25)
# Processing slice: Start = 0, End = 79, Shape = (80, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (80, 25)
# Processing slice: Start = 0, End = 80, Shape = (81, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (81, 25)
# Processing slice: Start = 0, End = 81, Shape = (82, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (82, 25)
# Processing slice: Start = 0, End = 82, Shape = (83, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (83, 25)
# Processing slice: Start = 0, End = 83, Shape = (84, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (84, 25)
# Processing slice: Start = 0, End = 84, Shape = (85, 25)
# 3/3 [==============================] - 0s 10ms/step
# Reconstructed shape: (85, 25)
# Processing slice: Start = 0, End = 85, Shape = (86, 25)
# 3/3 [==============================] - 0s 10ms/step
# Reconstructed shape: (86, 25)
# Processing slice: Start = 0, End = 86, Shape = (87, 25)
# 3/3 [==============================] - 0s 10ms/step
# Reconstructed shape: (87, 25)
# Processing slice: Start = 0, End = 87, Shape = (88, 25)
# 3/3 [==============================] - 0s 10ms/step
# Reconstructed shape: (88, 25)
# Processing slice: Start = 0, End = 88, Shape = (89, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (89, 25)
# Processing slice: Start = 0, End = 89, Shape = (90, 25)
# 3/3 [==============================] - 0s 10ms/step
# Reconstructed shape: (90, 25)
# Processing slice: Start = 0, End = 90, Shape = (91, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (91, 25)
# Processing slice: Start = 0, End = 91, Shape = (92, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (92, 25)
# Processing slice: Start = 0, End = 92, Shape = (93, 25)
# 3/3 [==============================] - 0s 10ms/step
# Reconstructed shape: (93, 25)
# Processing slice: Start = 0, End = 93, Shape = (94, 25)
# 3/3 [==============================] - 0s 7ms/step
# Reconstructed shape: (94, 25)
# Processing slice: Start = 0, End = 94, Shape = (95, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (95, 25)
# Processing slice: Start = 0, End = 95, Shape = (96, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (96, 25)
# Processing slice: Start = 0, End = 96, Shape = (97, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (97, 25)
# Processing slice: Start = 0, End = 97, Shape = (98, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (98, 25)
# Processing slice: Start = 0, End = 98, Shape = (99, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (99, 25)
# Processing slice: Start = 0, End = 99, Shape = (100, 25)
# 4/4 [==============================] - 0s 6ms/step
# Reconstructed shape: (100, 25)
# Processing slice: Start = 0, End = 100, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 1, End = 101, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 2, End = 102, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 3, End = 103, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 4, End = 104, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 5, End = 105, Shape = (101, 25)
# 4/4 [==============================] - 0s 6ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 6, End = 106, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 7, End = 107, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8, End = 108, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 9, End = 109, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 10, End = 110, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 11, End = 111, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 12, End = 112, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 13, End = 113, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 14, End = 114, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 15, End = 115, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 16, End = 116, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 17, End = 117, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 18, End = 118, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 19, End = 119, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 20, End = 120, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 21, End = 121, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 22, End = 122, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 23, End = 123, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 24, End = 124, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 25, End = 125, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 26, End = 126, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 27, End = 127, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 28, End = 128, Shape = (101, 25)
# 4/4 [==============================] - 0s 4ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 29, End = 129, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 30, End = 130, Shape = (101, 25)
# 4/4 [==============================] - 0s 6ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 31, End = 131, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 32, End = 132, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 33, End = 133, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 34, End = 134, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 35, End = 135, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 36, End = 136, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 37, End = 137, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 38, End = 138, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 39, End = 139, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 40, End = 140, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 41, End = 141, Shape = (101, 25)
# 4/4 [==============================] - 0s 5ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 42, End = 142, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start =
Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8395, End = 8495, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8396, End = 8496, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8397, End = 8497, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8398, End = 8498, Shape = (101, 25)
# 4/4 [==============================] - 0s 6ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8399, End = 8499, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8400, End = 8500, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8401, End = 8501, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8402, End = 8502, Shape = (101, 25)
# 4/4 [==============================] - 0s 301us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8403, End = 8503, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8404, End = 8504, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8405, End = 8505, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8406, End = 8506, Shape = (101, 25)
# 4/4 [==============================] - 0s 4ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8407, End = 8507, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8408, End = 8508, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# F1 Score: 0.9417680454176804
# Precision: 0.9989676531314522
# Recall: 0.8907640380484811
# False Negatives: 356
# False Positives: 3
# True Negatives: 5247
# True Positives: 2903
# C:\Users\AXW0J9E\AppData\Local\Temp\ipykernel_13192\1647934281.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9417680454176804' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_predictions.loc[final_predictions['chan_id'] == stream, 'f1'] = f1
# C:\Users\AXW0J9E\AppData\Local\Temp\ipykernel_13192\1647934281.py:26: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9989676531314522' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_predictions.loc[final_predictions['chan_id'] == stream, 'precision'] = precision
# C:\Users\AXW0J9E\AppData\Local\Temp\ipykernel_13192\1647934281.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.8907640380484811' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_predictions.loc[final_predictions['chan_id'] == stream, 'recall'] = recall
# C:\Users\AXW0J9E\AppData\Local\Temp\ipykernel_13192\1647934281.py:50: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   final_predictions.loc[final_predictions['chan_id'] == stream, 'predicted_anomalies'] = str(predicted_anomalies)

# %%
telemetry = pd.DataFrame(test_df[0])
telemetry.columns = ['telemetry']
telemetry
# Out:
#       telemetry
# 0     -0.684211
# 1     -0.684211
# 2     -0.684211
# 3     -0.684211
# 4     -0.684211
# ...         ...
# 8504   0.578947
# 8505   0.578947
# 8506   0.578947
# 8507   0.578947
# 8508   0.578947
#
# [8509 rows x 1 columns]

# %%
final_frame = pd.concat([final_df, telemetry], axis=1)
final_frame
# Out:
#       anomaly_score  recon_losses  actual_anomaly  predicted_labels  telemetry
# 0      9.834766e-07      0.000498             0.0                 0  -0.684211
# 1      9.834766e-07      0.000498             0.0                 0  -0.684211
# 2      9.834766e-07      0.000498             0.0                 0  -0.684211
# 3      9.834766e-07      0.000498             0.0                 0  -0.684211
# 4      9.834766e-07      0.000498             0.0                 0  -0.684211
# ...             ...           ...             ...               ...        ...
# 8504   6.632124e+00      0.284167             1.0                 1   0.578947
# 8505   6.632124e+00      0.284167             1.0                 1   0.578947
# 8506   6.632124e+00      0.284167             1.0                 1   0.578947
# 8507   6.632124e+00      0.284167             1.0                 1   0.578947
# 8508   6.632124e+00      0.284167             1.0                 1   0.578947
#
# [8509 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# Sort the DataFrame by index
data = final_frame.sort_index()

# Split the data into two DataFrames based on the predicted_labels
data_red = data[data['predicted_labels'] == 1]
data_blue = data[data['predicted_labels'] == 0]

# Plot the red segments
plt.plot(data_red.index, data_red['telemetry'], 'r', label='Predicted Anomaly')

# Plot the blue segments
plt.plot(data_blue.index, data_blue['telemetry'], 'b', label='Predicted Normal')

# Add a title and labels to the plot
plt.title('Telemetry with Predicted Labels')
plt.xlabel('Index')
plt.ylabel('Telemetry Value')

# Display the legend
plt.legend()

# Display the plot
plt.show()
