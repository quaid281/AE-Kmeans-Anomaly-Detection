# %%
import os
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import f1_score, silhouette_score, silhouette_samples
from scipy.spatial.distance import cosine
from scipy.cluster.vq import kmeans, vq

from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_predict, train_test_split
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Input, LSTM, BatchNormalization, Dropout, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12283080226929070080
# xla_global_id: -1
# ]

# %%
# Create relative path method to access all the files in data/raw/train folder
def relative_path(path):
    return os.path.join(os.getcwd(), path)

# %%
def evaluate(final_df, stream,final_predictions):
    # Calculate F1 Score
    f1 = f1_score(final_df['actual_anomaly'], final_df['predicted_labels'])
    print(f"F1 Score: {f1}")
    # True Positives
    tp_filter = (final_df['actual_anomaly'] == 1) & (final_df['predicted_labels'] == 1)
    # True Negatives
    tn_filter = (final_df['actual_anomaly'] == 0) & (final_df['predicted_labels'] == 0)
    # False Positives
    fp_filter = (final_df['actual_anomaly'] == 0) & (final_df['predicted_labels'] == 1)
    # False Negatives
    fn_filter = (final_df['actual_anomaly'] == 1) & (final_df['predicted_labels'] == 0)
    # Precision
    precision = len(final_df[tp_filter]) / (len(final_df[tp_filter]) + len(final_df[fp_filter]))
    # Recall
    recall = len(final_df[tp_filter]) / (len(final_df[tp_filter]) + len(final_df[fn_filter]))
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f'False Negatives: {len(final_df[fn_filter])}')
    print(f'False Positives: {len(final_df[fp_filter])}')
    print(f'True Negatives: {len(final_df[tn_filter])}')
    print(f'True Positives: {len(final_df[tp_filter])}')
    
    # Add evaluation Metrics to .csv file for on sample where chan_id == stream
    final_predictions.loc[final_predictions['chan_id'] == stream, 'f1'] = f1
    final_predictions.loc[final_predictions['chan_id'] == stream, 'precision'] = precision
    final_predictions.loc[final_predictions['chan_id'] == stream, 'recall'] = recall
    final_predictions.loc[final_predictions['chan_id'] == stream, 'tp'] = len(final_df[tp_filter])
    final_predictions.loc[final_predictions['chan_id'] == stream, 'tn'] = len(final_df[tn_filter])
    final_predictions.loc[final_predictions['chan_id'] == stream, 'fp'] = len(final_df[fp_filter])
    final_predictions.loc[final_predictions['chan_id'] == stream, 'fn'] = len(final_df[fn_filter])
    
    # calculate range or sequence of anomalies predicted
    predicted_anomalies = []
    start = 0
    end = 0
    while end < len(final_df):
        slice = final_df.iloc[start:end+1]
        if not slice.empty:
            if slice['predicted_labels'].iloc[0] == 1:
                if start == 0:
                    start = end
            else:
                if start != 0:
                    end = end - 1
                    predicted_anomalies.append([start,end])
                    start = 0
        if end < len(final_df):
            end += 1
    final_predictions.loc[final_predictions['chan_id'] == stream, 'predicted_anomalies'] = str(predicted_anomalies)
    return final_predictions

# %%
def train_autoencoder(train_df, test_df):
    # Split the data into train and test sets
    X_train, X_test = train_test_split(train_df.values, test_size=0.2, random_state=42)
    
    # Define the dimensions of the latent space
    latent_dim = 8
    input_dim = train_df.shape[1]
    
    # Create an autoencoder model with dropout layers
    # Do not use dropouts.  For some reason we can't build clusters when using dropout
    input_layer = keras.Input(shape=(train_df.shape[1],))
    encoded = layers.Dense(32, activation='tanh', activity_regularizer=regularizers.l1(0.01))(input_layer)
    encoded = layers.Dense(16, activation='tanh', activity_regularizer=regularizers.l1(0.01))(encoded)
    
    # Attention Mechanism
    # attention_probs = Dense(16, activation='softmax', name='attention_vec')(input_layer)  # Learn attention probabilities
    # attention_mul = Lambda(lambda x: x[0] * x[1], name='attention_mul')([encoded, attention_probs])
    
    # Latent layer with attention
    latent_layer = Dense(latent_dim, activation='tanh', activity_regularizer=regularizers.l1(0.01))(encoded)
    

    # Decoder
    decoded = layers.Dense(16, activation='tanh', activity_regularizer=regularizers.l1(0.01))(latent_layer)
    decoded = layers.Dense(32, activation='tanh', activity_regularizer=regularizers.l1(0.01))(decoded)
    decoded = layers.Dense(input_dim, activation='tanh')(decoded)

    autoencoder = keras.Model(input_layer, decoded)

    # Compile the autoencoder with gradient clipping
    optimizer = Adam(clipnorm=1.0)  # Clip gradients by their norm
    autoencoder.compile(optimizer=optimizer, loss='mse')

    # Define Early Stopping and Reduce Learning Rate callbacks
    early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001, verbose=1)

    # Train the autoencoder with callbacks
    history = autoencoder.fit(
        X_train, X_train,
        epochs=300,
        batch_size=32,
        shuffle=True,
        validation_data=(X_test, X_test),  # Validation data for early stopping
        callbacks=[early_stopping, reduce_lr]  # Pass the callbacks
    )

    encoder = keras.Model(input_layer, encoded)
    # Encode entire dataset
    test_latent_representation = encoder.predict(test_df.values)
    train_latent_representation = encoder.predict(train_df.values)
    return test_latent_representation, train_latent_representation, autoencoder

# %%
def get_reconstruction_loss(autoencoder, test_df,final_df):
    max_window_size = 100
    recon_losses = []
    start = 0
    end = 0

    while end < len(test_df):
        slice = test_df.iloc[start:end+1]
        print(f"Processing slice: Start = {start}, End = {end}, Shape = {slice.shape}")

        # Check if the slice is empty
        if not slice.empty:
            # Reconstruct slice
            recon = autoencoder.predict(slice.values)
            print(f"Reconstructed shape: {recon.shape}")

            # Calculate recon loss for the entire slice
            loss = np.mean(np.square(slice.values - recon), axis=1)
            mean_loss = np.mean(loss)
            recon_losses.append(mean_loss)

        # Increment the start by 1 if the end is greater than or equal to the max window size
        if end >= max_window_size:
            start += 1

        # Check if end has reached the end of the DataFrame
        if end < len(test_df):
            end += 1
    final_df['recon_losses'] = recon_losses
    return final_df

# %%
def perform_kmeans_with_refinement(test_latent_representation, train_latent_representation, k_values, final_df, max_iter=400, random_state=42):
    """
    Perform K-Means clustering with iterative refinement based on silhouette score.

    Parameters:
    - X: Input data (features) as a DataFrame or numpy array.
    - k_values: List of K values to consider.
    - n_init: Number of times the K-Means algorithm will be run with different centroid seeds.
    - max_iter: Maximum number of iterations for each run of the K-Means algorithm.
    - random_state: Seed for randomization (optional).

    Returns:
    - Tuple containing (best_K, best_score, cluster_labels).
    """
    
    if isinstance(test_latent_representation, pd.DataFrame):
        test_latent_representation = test_latent_representation.values  # if dataframe Convert DataFrame to numpy array

    if isinstance(train_latent_representation, pd.DataFrame):
        train_latent_representation = train_latent_representation.values  # if dataframe Convert DataFrame to numpy array
    
    scaler = StandardScaler()
    train_latent_representation = scaler.fit_transform(train_latent_representation)
    test_latent_representation = scaler.transform(test_latent_representation)
    
    best_k = None
    best_silhouette_score = -1

    for k in k_values:
        print(f"Current k value: {k}")
        kmeans = KMeans(n_clusters=k, n_init=20, init='k-means++', max_iter=max_iter, random_state=random_state).fit(train_latent_representation)
        labels = kmeans.predict(train_latent_representation)

        # Calculate the silhouette score
        silhouette_values = silhouette_samples(train_latent_representation, labels, metric='euclidean')

        # Calculate the weighted average of the silhouette coefficients
        silhouette_avg = np.mean(silhouette_values)
        print(f"Silhouette score: {silhouette_avg}")

        # Check if this is the best silhouette score so far
        if silhouette_avg > best_silhouette_score:
            best_k = k
            best_silhouette_score = silhouette_avg

    
    print(f"Best K: {best_k}")
    print(f"Best Silhouette Score: {best_silhouette_score}")
    
    kmeans = KMeans(n_clusters=best_k, n_init=20, init='k-means++',max_iter=max_iter,random_state=random_state).fit(train_latent_representation)

    # Predicting the cluster labels for the test set
    cluster_labels = kmeans.predict(test_latent_representation)

    # Computing the distances of samples in test set to all cluster centers
    distances = kmeans.transform(test_latent_representation)

    # Extracting the distances of each sample to its assigned cluster
    distances_to_assigned_cluster = distances[np.arange(len(distances)), cluster_labels]
    cluster_centers = kmeans.cluster_centers_
    # Graph Cluster_centers
    plt.figure(figsize=(10, 6))
    plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], marker='x', s=100, c='r')
    plt.title('Cluster Centers')
    plt.xlabel('Feature 0')
    plt.ylabel('Feature 1')
    plt.show()
    final_df['anomaly_score'] = distances_to_assigned_cluster
    return final_df

# %%
import matplotlib.patches as patches

def perform_thresholding(final_df):
    X = final_df[['anomaly_score', 'recon_losses']].values
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    # Separate the normal and anomalous points
    normal_points = X[final_df['actual_anomaly'] == 0]
    anomalous_points = X[final_df['actual_anomaly'] == 1]

    # Create separate scatter plots for the normal and anomalous points
    plt.scatter(normal_points[:, 0], normal_points[:, 1], c='blue', label='Normal')
    plt.scatter(anomalous_points[:, 0], anomalous_points[:, 1], c='red', label='Anomalous')

    plt.xlabel('Anomaly Score')
    plt.ylabel('Reconstruction Loss')

    nbrs = NearestNeighbors(n_neighbors=6000)
    nbrs.fit(X)
    distances, indices = nbrs.kneighbors(X)

    threshold = np.mean(distances)

    # Add a circle representing the decision boundary
    circle = patches.Circle((0, 0), threshold, fill=False, color='green')
    plt.gca().add_patch(circle)

    # Add a legend
    plt.legend()

    plt.show()

    predicted_labels = np.where(distances.mean(axis=1) > threshold, 1, 0)
    final_df['predicted_labels'] = predicted_labels

    return final_df

# %%
def distances_recon_concat_ground_truth(final_df, labeled_anomalies, stream):
    anomaly_sequences = labeled_anomalies[labeled_anomalies['chan_id'] == stream]['anomaly_sequences'].tolist()
    actual_anomalies = [eval(seq) for seq in anomaly_sequences]
    
    # Initialize a binary array with zeros
    binary_labels = np.zeros(final_df.shape[0])

    # Check if actual_anomalies is a nested list
    if len(actual_anomalies) == 1 and isinstance(actual_anomalies[0], list) and len(actual_anomalies[0]) == 1:
        # Handle nested structure
        anomaly_sequence = actual_anomalies[0][0]
        start, end = anomaly_sequence[0], anomaly_sequence[1]
        binary_labels[start:end + 1] = 1
    else:
        # Handle non-nested structure (single-index anomalies)
        for sequence in actual_anomalies:
            if isinstance(sequence, int):
                binary_labels[sequence] = 1
    binary_frame = pd.DataFrame(binary_labels, columns=['actual_anomaly'])
    
    # Concatenate the DataFrames
    final_df = pd.concat([final_df, binary_frame], axis=1)
    return final_df

# %%
parent_dir = os.path.dirname(os.getcwd())
channels_folder = os.path.join(parent_dir, 'data','raw','train')
channels = os.listdir(channels_folder)

labeled_anomalies_file = os.path.join(parent_dir, 'data','processed','labeled_anomalies.csv')
labeled_anomalies = pd.read_csv(labeled_anomalies_file)
channel = 'D-1.npy'

final_predictions = labeled_anomalies.copy()
# Add a columns for f1 score, precision, recall, tp, tn, fp, fn to final predictions dataframe
final_predictions['f1'] = 0
final_predictions['precision'] = 0
final_predictions['recall'] = 0
final_predictions['tp'] = 0
final_predictions['tn'] = 0
final_predictions['fp'] = 0
final_predictions['fn'] = 0
final_predictions['predicted_anomaly_sequences'] = 0
stream = channel[:-4]
final_df = pd.DataFrame()    
print(f'Currently working on {stream} Channel')

train_df = pd.DataFrame(np.load(os.path.join(parent_dir, 'data','raw','train',f'{channel}')))
test_df = pd.DataFrame(np.load(os.path.join(parent_dir, 'data','raw','test',f'{channel}')))

test_latent_representation, train_latent_representation, autoencoder = train_autoencoder(train_df, test_df)

# Perform K-Means clustering with iterative refinement based on silhouette score\
final_df  = perform_kmeans_with_refinement(test_latent_representation, train_latent_representation, range(3,60), final_df)
# Perform Sliding Window Autoencoder to get reconstruction loss
final_df  = get_reconstruction_loss(autoencoder, test_df,final_df)
final_df  = distances_recon_concat_ground_truth(final_df, labeled_anomalies, stream)
final_df  = perform_thresholding(final_df)
    
final_predictions = evaluate(final_df, stream, final_predictions)
# Out:
# Currently working on D-1 Channel
# Epoch 1/300
# 72/72 [==============================] - 2s 7ms/step - loss: 0.1063 - val_loss: 0.0787 - lr: 0.0010
# Epoch 2/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0582 - val_loss: 0.0520 - lr: 0.0010
# Epoch 3/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0399 - val_loss: 0.0391 - lr: 0.0010
# Epoch 4/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0314 - val_loss: 0.0330 - lr: 0.0010
# Epoch 5/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0270 - val_loss: 0.0289 - lr: 0.0010
# Epoch 6/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0242 - val_loss: 0.0264 - lr: 0.0010
# Epoch 7/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0220 - val_loss: 0.0248 - lr: 0.0010
# Epoch 8/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0203 - val_loss: 0.0225 - lr: 0.0010
# Epoch 9/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0188 - val_loss: 0.0211 - lr: 0.0010
# Epoch 10/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0196 - lr: 0.0010
# Epoch 11/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0166 - val_loss: 0.0188 - lr: 0.0010
# Epoch 12/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0161 - val_loss: 0.0180 - lr: 0.0010
# Epoch 13/300
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0148 - val_loss: 0.0173 - lr: 0.0010
# Epoch 14/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0140 - val_loss: 0.0161 - lr: 0.0010
# Epoch 15/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0135 - val_loss: 0.0155 - lr: 0.0010
# Epoch 16/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0130 - val_loss: 0.0150 - lr: 0.0010
# Epoch 17/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0124 - val_loss: 0.0146 - lr: 0.0010
# Epoch 18/300
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0120 - val_loss: 0.0139 - lr: 0.0010
# Epoch 19/300
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0113 - val_loss: 0.0135 - lr: 0.0010
# Epoch 20/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0113 - val_loss: 0.0143 - lr: 0.0010
# Epoch 21/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0111 - val_loss: 0.0131 - lr: 0.0010
# Epoch 22/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0104 - val_loss: 0.0126 - lr: 0.0010
# Epoch 23/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0125 - lr: 0.0010
# Epoch 24/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0125 - lr: 0.0010
# Epoch 25/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0116 - lr: 0.0010
# Epoch 26/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0110 - lr: 0.0010
# Epoch 27/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0090 - val_loss: 0.0112 - lr: 0.0010
# Epoch 28/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0106 - lr: 0.0010
# Epoch 29/300
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0086 - val_loss: 0.0102 - lr: 0.0010
# Epoch 30/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0083 - val_loss: 0.0102 - lr: 0.0010
# Epoch 31/300
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0098 - lr: 0.0010
# Epoch 32/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0096 - lr: 0.0010
# Epoch 33/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0095 - lr: 0.0010
# Epoch 34/300
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.0094 - lr: 0.0010
# Epoch 35/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0089 - lr: 0.0010
# Epoch 36/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0095 - lr: 0.0010
# Epoch 37/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0099 - lr: 0.0010
# Epoch 38/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0086 - lr: 0.0010
# Epoch 39/300
# 72/72 [==============================] - 0s 1ms/step - loss: 0.0071 - val_loss: 0.0085 - lr: 0.0010
# Epoch 40/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0084 - lr: 0.0010
# Epoch 41/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0083 - lr: 0.0010
# Epoch 42/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0082 - lr: 0.0010
# Epoch 43/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0085 - lr: 0.0010
# Epoch 44/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0081 - lr: 0.0010
# Epoch 45/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0084 - lr: 0.0010
# Epoch 46/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0080 - lr: 0.0010
# Epoch 47/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0079 - lr: 0.0010
# Epoch 48/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0077 - lr: 0.0010
# Epoch 49/300
# 72/72 [==============================] - 0s 1ms/step - loss: 0.0064 - val_loss: 0.0081 - lr: 0.0010
# Epoch 50/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0082 - lr: 0.0010
# Epoch 51/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0076 - lr: 0.0010
# Epoch 52/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0081 - lr: 0.0010
# Epoch 53/300
# 46/72 [==================>...........] - ETA: 0s - loss: 0.0063
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0076 - lr: 0.0010
# Epoch 54/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0069 - lr: 2.0000e-04
# Epoch 55/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0068 - lr: 2.0000e-04
# Epoch 56/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0068 - lr: 2.0000e-04
# Epoch 57/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0067 - lr: 2.0000e-04
# Epoch 58/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0067 - lr: 2.0000e-04
# Epoch 59/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0068 - lr: 2.0000e-04
# Epoch 60/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0067 - lr: 2.0000e-04
# Epoch 61/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0067 - lr: 2.0000e-04
# Epoch 62/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0067 - lr: 2.0000e-04
# Epoch 63/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0066 - lr: 2.0000e-04
# Epoch 64/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0066 - lr: 2.0000e-04
# Epoch 65/300
# 67/72 [==========================>...] - ETA: 0s - loss: 0.0054
# Epoch 65: ReduceLROnPlateau reducing learning rate to 0.0001.
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0066 - lr: 2.0000e-04
# Epoch 66/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0065 - lr: 1.0000e-04
# Epoch 67/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0065 - lr: 1.0000e-04
# Epoch 68/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0065 - lr: 1.0000e-04
# Epoch 69/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0065 - lr: 1.0000e-04
# Epoch 70/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0065 - lr: 1.0000e-04
# Epoch 71/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0065 - lr: 1.0000e-04
# Epoch 72/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0065 - lr: 1.0000e-04
# Epoch 73/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0065 - lr: 1.0000e-04
# Epoch 74/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0064 - lr: 1.0000e-04
# Epoch 75/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0064 - lr: 1.0000e-04
# Epoch 76/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0064 - lr: 1.0000e-04
# Epoch 77/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0064 - lr: 1.0000e-04
# Epoch 78/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0064 - lr: 1.0000e-04
# Epoch 79/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0064 - lr: 1.0000e-04
# Epoch 80/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0063 - lr: 1.0000e-04
# Epoch 81/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0064 - lr: 1.0000e-04
# Epoch 82/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0064 - lr: 1.0000e-04
# Epoch 83/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0063 - lr: 1.0000e-04
# Epoch 84/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0063 - lr: 1.0000e-04
# Epoch 85/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0063 - lr: 1.0000e-04
# Epoch 86/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0063 - lr: 1.0000e-04
# Epoch 87/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0063 - lr: 1.0000e-04
# Epoch 88/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0063 - lr: 1.0000e-04
# Epoch 89/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 90/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 91/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 92/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 93/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 94/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 95/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 96/300
# 72/72 [==============================] - 0s 1ms/step - loss: 0.0050 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 97/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 98/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 99/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0061 - lr: 1.0000e-04
# Epoch 100/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0061 - lr: 1.0000e-04
# Epoch 101/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0061 - lr: 1.0000e-04
# Epoch 102/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0061 - lr: 1.0000e-04
# Epoch 103/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0061 - lr: 1.0000e-04
# Epoch 104/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0061 - lr: 1.0000e-04
# Epoch 105/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0061 - lr: 1.0000e-04
# Epoch 106/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0061 - lr: 1.0000e-04
# Epoch 107/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0060 - lr: 1.0000e-04
# Epoch 108/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0061 - lr: 1.0000e-04
# Epoch 109/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0060 - lr: 1.0000e-04
# Epoch 110/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0060 - lr: 1.0000e-04
# Epoch 111/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0060 - lr: 1.0000e-04
# Epoch 112/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0060 - lr: 1.0000e-04
# Epoch 113/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0060 - lr: 1.0000e-04
# Epoch 114/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0060 - lr: 1.0000e-04
# Epoch 115/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0060 - lr: 1.0000e-04
# Epoch 116/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0060 - lr: 1.0000e-04
# Epoch 117/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0059 - lr: 1.0000e-04
# Epoch 118/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0060 - lr: 1.0000e-04
# Epoch 119/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0059 - lr: 1.0000e-04
# Epoch 120/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0059 - lr: 1.0000e-04
# Epoch 121/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0059 - lr: 1.0000e-04
# Epoch 122/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0059 - lr: 1.0000e-04
# Epoch 123/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0059 - lr: 1.0000e-04
# Epoch 124/300
# 72/72 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 125/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0048 - val_loss: 0.0059 - lr: 1.0000e-04
# Epoch 126/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 127/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 128/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 129/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 130/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 131/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0059 - lr: 1.0000e-04
# Epoch 132/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 133/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 134/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 135/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 136/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 137/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0057 - lr: 1.0000e-04
# Epoch 138/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 139/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0057 - lr: 1.0000e-04
# Epoch 140/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0057 - lr: 1.0000e-04
# Epoch 141/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0057 - lr: 1.0000e-04
# Epoch 142/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0057 - lr: 1.0000e-04
# Epoch 143/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0057 - lr: 1.0000e-04
# Epoch 144/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0057 - lr: 1.0000e-04
# Epoch 145/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0056 - lr: 1.0000e-04
# Epoch 146/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0057 - lr: 1.0000e-04
# Epoch 147/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0056 - lr: 1.0000e-04
# Epoch 148/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0056 - lr: 1.0000e-04
# Epoch 149/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0057 - lr: 1.0000e-04
# Epoch 150/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0057 - lr: 1.0000e-04
# Epoch 151/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 152/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0046 - val_loss: 0.0056 - lr: 1.0000e-04
# Epoch 153/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0057 - lr: 1.0000e-04
# Epoch 154/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0056 - lr: 1.0000e-04
# Epoch 155/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0056 - lr: 1.0000e-04
# Epoch 156/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0056 - lr: 1.0000e-04
# Epoch 157/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 158/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 159/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 160/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 161/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 162/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 163/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 164/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0045 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 165/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 166/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 167/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 168/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0054 - lr: 1.0000e-04
# Epoch 169/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 170/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 171/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0054 - lr: 1.0000e-04
# Epoch 172/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0054 - lr: 1.0000e-04
# Epoch 173/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0054 - lr: 1.0000e-04
# Epoch 174/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0054 - lr: 1.0000e-04
# Epoch 175/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0054 - lr: 1.0000e-04
# Epoch 176/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0044 - val_loss: 0.0054 - lr: 1.0000e-04
# Epoch 177/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0054 - lr: 1.0000e-04
# Epoch 178/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 179/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 180/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 181/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0054 - lr: 1.0000e-04
# Epoch 182/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0054 - lr: 1.0000e-04
# Epoch 183/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0054 - lr: 1.0000e-04
# Epoch 184/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 185/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 186/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 187/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 188/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 189/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 190/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 191/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0043 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 192/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 193/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 194/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 195/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 196/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 197/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 198/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 199/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 200/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 201/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 202/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 203/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0051 - lr: 1.0000e-04
# Epoch 204/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0042 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 205/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0051 - lr: 1.0000e-04
# Epoch 206/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0051 - lr: 1.0000e-04
# Epoch 207/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0051 - lr: 1.0000e-04
# Epoch 208/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0051 - lr: 1.0000e-04
# Epoch 209/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0051 - lr: 1.0000e-04
# Epoch 210/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 211/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0051 - lr: 1.0000e-04
# Epoch 212/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 213/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 214/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 215/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 216/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 217/300
# 72/72 [==============================] - 0s 1ms/step - loss: 0.0041 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 218/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 219/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 220/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0041 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 221/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 222/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 223/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 224/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 225/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 226/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 227/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 228/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 229/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 230/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 231/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 232/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 233/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 234/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 235/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 236/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 237/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0040 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 238/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 239/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 240/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 241/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 242/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 243/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 244/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 245/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 246/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 247/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 248/300
# 72/72 [==============================] - 0s 1ms/step - loss: 0.0039 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 249/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 250/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 251/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 252/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 253/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 254/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 255/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 256/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 257/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 258/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 259/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 260/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 261/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 262/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 263/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 264/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 265/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 266/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 267/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 268/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 269/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 270/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 271/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 272/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 273/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 274/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0038 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 275/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 276/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 277/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 278/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 279/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 280/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 281/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 282/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 283/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 284/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 285/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 286/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 287/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 288/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 289/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 290/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 291/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 292/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0046 - lr: 1.0000e-04
# Epoch 293/300
# 72/72 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 294/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 295/300
# 72/72 [==============================] - 0s 1ms/step - loss: 0.0037 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 296/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0044 - lr: 1.0000e-04
# Epoch 297/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0044 - lr: 1.0000e-04
# Epoch 298/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0044 - lr: 1.0000e-04
# Epoch 299/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0044 - lr: 1.0000e-04
# Epoch 300/300
# 72/72 [==============================] - 0s 2ms/step - loss: 0.0036 - val_loss: 0.0044 - lr: 1.0000e-04
# 266/266 [==============================] - 0s 789us/step
# 90/90 [==============================] - 0s 668us/step
# Current k value: 3
# Silhouette score: 0.8495855331420898
# Current k value: 4
# Silhouette score: 0.8479671478271484
# Current k value: 5
# Silhouette score: 0.8404064178466797
# Current k value: 6
# Silhouette score: 0.8433655500411987
# Current k value: 7
# Silhouette score: 0.8571419715881348
# Current k value: 8
# Silhouette score: 0.8610624670982361
# Current k value: 9
# Silhouette score: 0.8974030017852783
# Current k value: 10
# Silhouette score: 0.9274744391441345
# Current k value: 11
# Silhouette score: 0.9212731122970581
# Current k value: 12
# Silhouette score: 0.9408042430877686
# Current k value: 13
# Silhouette score: 0.9508219957351685
# Current k value: 14
# Silhouette score: 0.9511339068412781
# Current k value: 15
# Silhouette score: 0.9564186334609985
# Current k value: 16
# Silhouette score: 0.9666830897331238
# Current k value: 17
# Silhouette score: 0.9708319902420044
# Current k value: 18
# Silhouette score: 0.9763669371604919
# Current k value: 19
# Silhouette score: 0.9811498522758484
# Current k value: 20
# Silhouette score: 0.9950655102729797
# Current k value: 21
# Silhouette score: 0.9951571822166443
# Current k value: 22
# Silhouette score: 0.9946233630180359
# Current k value: 23
# Silhouette score: 0.9957644939422607
# Current k value: 24
# Silhouette score: 0.9961881637573242
# Current k value: 25
# Silhouette score: 0.9960572719573975
# Current k value: 26
# Silhouette score: 0.995945930480957
# Current k value: 27
# Silhouette score: 0.9958359599113464
# Current k value: 28
# Silhouette score: 0.9957311749458313
# Current k value: 29
# Silhouette score: 0.9950342178344727
# Current k value: 30
# Silhouette score: 0.7280177474021912
# Current k value: 31
# Silhouette score: 0.8283773064613342
# Current k value: 32
# Silhouette score: 0.8284012079238892
# Current k value: 33
# Silhouette score: 0.8277007937431335
# Current k value: 34
# Silhouette score: 0.8974464535713196
# Current k value: 35
# Silhouette score: 0.9709104895591736
# Current k value: 36
# Silhouette score: 0.9702107906341553
# Current k value: 37
# Silhouette score: 0.9682391881942749
# Current k value: 38
# Silhouette score: 0.9668155312538147
# Current k value: 39
# Silhouette score: 0.9655651450157166
# Current k value: 40
# Silhouette score: 0.9866442680358887
# Current k value: 41
# Silhouette score: 0.9862937331199646
# Current k value: 42
# Silhouette score: 0.9846473336219788
# Current k value: 43
# Silhouette score: 0.9850455522537231
# Current k value: 44
# Silhouette score: 0.9853782057762146
# Current k value: 45
# Silhouette score: 0.9850450158119202
# Current k value: 46
# Silhouette score: 0.9851289391517639
# Current k value: 47
# Silhouette score: 0.9829198122024536
# Current k value: 48
# Silhouette score: 0.9813269972801208
# Current k value: 49
# Silhouette score: 0.9824187755584717
# Current k value: 50
# Silhouette score: 0.9820204973220825
# Current k value: 51
# Silhouette score: 0.9829679131507874
# Current k value: 52
# Silhouette score: 0.9828434586524963
# Current k value: 53
# Silhouette score: 0.9825001955032349
# Current k value: 54
# Silhouette score: 0.9836354851722717
# Current k value: 55
# Silhouette score: 0.9811103343963623
# Current k value: 56
# Silhouette score: 0.9806739091873169
# Current k value: 57
# Silhouette score: 0.983275830745697
# Current k value: 58
# Silhouette score: 0.9845321774482727
# Current k value: 59
# Silhouette score: 0.9854761362075806
# Best K: 24
# Best Silhouette Score: 0.9961881637573242
# Processing slice: Start = 0, End = 0, Shape = (1, 25)
# 1/1 [==============================] - 0s 56ms/step
# Reconstructed shape: (1, 25)
# Processing slice: Start = 0, End = 1, Shape = (2, 25)
# 1/1 [==============================] - 0s 13ms/step
# Reconstructed shape: (2, 25)
# Processing slice: Start = 0, End = 2, Shape = (3, 25)
# 1/1 [==============================] - 0s 13ms/step
# Reconstructed shape: (3, 25)
# Processing slice: Start = 0, End = 3, Shape = (4, 25)
# 1/1 [==============================] - 0s 15ms/step
# Reconstructed shape: (4, 25)
# Processing slice: Start = 0, End = 4, Shape = (5, 25)
# 1/1 [==============================] - 0s 7ms/step
# Reconstructed shape: (5, 25)
# Processing slice: Start = 0, End = 5, Shape = (6, 25)
# 1/1 [==============================] - 0s 3ms/step
# Reconstructed shape: (6, 25)
# Processing slice: Start = 0, End = 6, Shape = (7, 25)
# 1/1 [==============================] - 0s 13ms/step
# Reconstructed shape: (7, 25)
# Processing slice: Start = 0, End = 7, Shape = (8, 25)
# 1/1 [==============================] - 0s 15ms/step
# Reconstructed shape: (8, 25)
# Processing slice: Start = 0, End = 8, Shape = (9, 25)
# 1/1 [==============================] - 0s 12ms/step
# Reconstructed shape: (9, 25)
# Processing slice: Start = 0, End = 9, Shape = (10, 25)
# 1/1 [==============================] - 0s 13ms/step
# Reconstructed shape: (10, 25)
# Processing slice: Start = 0, End = 10, Shape = (11, 25)
# 1/1 [==============================] - 0s 13ms/step
# Reconstructed shape: (11, 25)
# Processing slice: Start = 0, End = 11, Shape = (12, 25)
# 1/1 [==============================] - 0s 19ms/step
# Reconstructed shape: (12, 25)
# Processing slice: Start = 0, End = 12, Shape = (13, 25)
# 1/1 [==============================] - 0s 20ms/step
# Reconstructed shape: (13, 25)
# Processing slice: Start = 0, End = 13, Shape = (14, 25)
# 1/1 [==============================] - 0s 22ms/step
# Reconstructed shape: (14, 25)
# Processing slice: Start = 0, End = 14, Shape = (15, 25)
# 1/1 [==============================] - 0s 12ms/step
# Reconstructed shape: (15, 25)
# Processing slice: Start = 0, End = 15, Shape = (16, 25)
# 1/1 [==============================] - 0s 16ms/step
# Reconstructed shape: (16, 25)
# Processing slice: Start = 0, End = 16, Shape = (17, 25)
# 1/1 [==============================] - 0s 18ms/step
# Reconstructed shape: (17, 25)
# Processing slice: Start = 0, End = 17, Shape = (18, 25)
# 1/1 [==============================] - 0s 7ms/step
# Reconstructed shape: (18, 25)
# Processing slice: Start = 0, End = 18, Shape = (19, 25)
# 1/1 [==============================] - 0s 10ms/step
# Reconstructed shape: (19, 25)
# Processing slice: Start = 0, End = 19, Shape = (20, 25)
# 1/1 [==============================] - 0s 9ms/step
# Reconstructed shape: (20, 25)
# Processing slice: Start = 0, End = 20, Shape = (21, 25)
# 1/1 [==============================] - 0s 9ms/step
# Reconstructed shape: (21, 25)
# Processing slice: Start = 0, End = 21, Shape = (22, 25)
# 1/1 [==============================] - 0s 12ms/step
# Reconstructed shape: (22, 25)
# Processing slice: Start = 0, End = 22, Shape = (23, 25)
# 1/1 [==============================] - 0s 13ms/step
# Reconstructed shape: (23, 25)
# Processing slice: Start = 0, End = 23, Shape = (24, 25)
# 1/1 [==============================] - 0s 12ms/step
# Reconstructed shape: (24, 25)
# Processing slice: Start = 0, End = 24, Shape = (25, 25)
# 1/1 [==============================] - 0s 16ms/step
# Reconstructed shape: (25, 25)
# Processing slice: Start = 0, End = 25, Shape = (26, 25)
# 1/1 [==============================] - 0s 29ms/step
# Reconstructed shape: (26, 25)
# Processing slice: Start = 0, End = 26, Shape = (27, 25)
# 1/1 [==============================] - 0s 23ms/step
# Reconstructed shape: (27, 25)
# Processing slice: Start = 0, End = 27, Shape = (28, 25)
# 1/1 [==============================] - 0s 14ms/step
# Reconstructed shape: (28, 25)
# Processing slice: Start = 0, End = 28, Shape = (29, 25)
# 1/1 [==============================] - 0s 14ms/step
# Reconstructed shape: (29, 25)
# Processing slice: Start = 0, End = 29, Shape = (30, 25)
# 1/1 [==============================] - 0s 20ms/step
# Reconstructed shape: (30, 25)
# Processing slice: Start = 0, End = 30, Shape = (31, 25)
# 1/1 [==============================] - 0s 7ms/step
# Reconstructed shape: (31, 25)
# Processing slice: Start = 0, End = 31, Shape = (32, 25)
# 1/1 [==============================] - 0s 13ms/step
# Reconstructed shape: (32, 25)
# Processing slice: Start = 0, End = 32, Shape = (33, 25)
# 2/2 [==============================] - 0s 4ms/step
# Reconstructed shape: (33, 25)
# Processing slice: Start = 0, End = 33, Shape = (34, 25)
# 2/2 [==============================] - 0s 2ms/step
# Reconstructed shape: (34, 25)
# Processing slice: Start = 0, End = 34, Shape = (35, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (35, 25)
# Processing slice: Start = 0, End = 35, Shape = (36, 25)
# 2/2 [==============================] - 0s 0s/step
# Reconstructed shape: (36, 25)
# Processing slice: Start = 0, End = 36, Shape = (37, 25)
# 2/2 [==============================] - 0s 2ms/step
# Reconstructed shape: (37, 25)
# Processing slice: Start = 0, End = 37, Shape = (38, 25)
# 2/2 [==============================] - 0s 1ms/step
# Reconstructed shape: (38, 25)
# Processing slice: Start = 0, End = 38, Shape = (39, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (39, 25)
# Processing slice: Start = 0, End = 39, Shape = (40, 25)
# 2/2 [==============================] - 0s 2ms/step
# Reconstructed shape: (40, 25)
# Processing slice: Start = 0, End = 40, Shape = (41, 25)
# 2/2 [==============================] - 0s 1ms/step
# Reconstructed shape: (41, 25)
# Processing slice: Start = 0, End = 41, Shape = (42, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (42, 25)
# Processing slice: Start = 0, End = 42, Shape = (43, 25)
# 2/2 [==============================] - 0s 759us/step
# Reconstructed shape: (43, 25)
# Processing slice: Start = 0, End = 43, Shape = (44, 25)
# 2/2 [==============================] - 0s 1ms/step
# Reconstructed shape: (44, 25)
# Processing slice: Start = 0, End = 44, Shape = (45, 25)
# 2/2 [==============================] - 0s 0s/step
# Reconstructed shape: (45, 25)
# Processing slice: Start = 0, End = 45, Shape = (46, 25)
# 2/2 [==============================] - 0s 2ms/step
# Reconstructed shape: (46, 25)
# Processing slice: Start = 0, End = 46, Shape = (47, 25)
# 2/2 [==============================] - 0s 1000us/step
# Reconstructed shape: (47, 25)
# Processing slice: Start = 0, End = 47, Shape = (48, 25)
# 2/2 [==============================] - 0s 0s/step
# Reconstructed shape: (48, 25)
# Processing slice: Start = 0, End = 48, Shape = (49, 25)
# 2/2 [==============================] - 0s 10ms/step
# Reconstructed shape: (49, 25)
# Processing slice: Start = 0, End = 49, Shape = (50, 25)
# 2/2 [==============================] - 0s 0s/step
# Reconstructed shape: (50, 25)
# Processing slice: Start = 0, End = 50, Shape = (51, 25)
# 2/2 [==============================] - 0s 0s/step
# Reconstructed shape: (51, 25)
# Processing slice: Start = 0, End = 51, Shape = (52, 25)
# 2/2 [==============================] - 0s 1ms/step
# Reconstructed shape: (52, 25)
# Processing slice: Start = 0, End = 52, Shape = (53, 25)
# 2/2 [==============================] - 0s 2ms/step
# Reconstructed shape: (53, 25)
# Processing slice: Start = 0, End = 53, Shape = (54, 25)
# 2/2 [==============================] - 0s 1ms/step
# Reconstructed shape: (54, 25)
# Processing slice: Start = 0, End = 54, Shape = (55, 25)
# 2/2 [==============================] - 0s 0s/step
# Reconstructed shape: (55, 25)
# Processing slice: Start = 0, End = 55, Shape = (56, 25)
# 2/2 [==============================] - 0s 0s/step
# Reconstructed shape: (56, 25)
# Processing slice: Start = 0, End = 56, Shape = (57, 25)
# 2/2 [==============================] - 0s 1ms/step
# Reconstructed shape: (57, 25)
# Processing slice: Start = 0, End = 57, Shape = (58, 25)
# 2/2 [==============================] - 0s 0s/step
# Reconstructed shape: (58, 25)
# Processing slice: Start = 0, End = 58, Shape = (59, 25)
# 2/2 [==============================] - 0s 2ms/step
# Reconstructed shape: (59, 25)
# Processing slice: Start = 0, End = 59, Shape = (60, 25)
# 2/2 [==============================] - 0s 0s/step
# Reconstructed shape: (60, 25)
# Processing slice: Start = 0, End = 60, Shape = (61, 25)
# 2/2 [==============================] - 0s 998us/step
# Reconstructed shape: (61, 25)
# Processing slice: Start = 0, End = 61, Shape = (62, 25)
# 2/2 [==============================] - 0s 2ms/step
# Reconstructed shape: (62, 25)
# Processing slice: Start = 0, End = 62, Shape = (63, 25)
# 2/2 [==============================] - 0s 0s/step
# Reconstructed shape: (63, 25)
# Processing slice: Start = 0, End = 63, Shape = (64, 25)
# 2/2 [==============================] - 0s 2ms/step
# Reconstructed shape: (64, 25)
# Processing slice: Start = 0, End = 64, Shape = (65, 25)
# 3/3 [==============================] - 0s 1000us/step
# Reconstructed shape: (65, 25)
# Processing slice: Start = 0, End = 65, Shape = (66, 25)
# 3/3 [==============================] - 0s 999us/step
# Reconstructed shape: (66, 25)
# Processing slice: Start = 0, End = 66, Shape = (67, 25)
# 3/3 [==============================] - 0s 5ms/step
# Reconstructed shape: (67, 25)
# ...
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8310, End = 8410, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8311, End = 8411, Shape = (101, 25)
# 4/4 [==============================] - 0s 591us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8312, End = 8412, Shape = (101, 25)
# 4/4 [==============================] - 0s 5ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8313, End = 8413, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8314, End = 8414, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8315, End = 8415, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8316, End = 8416, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8317, End = 8417, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8318, End = 8418, Shape = (101, 25)
# 4/4 [==============================] - 0s 692us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8319, End = 8419, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8320, End = 8420, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8321, End = 8421, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8322, End = 8422, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8323, End = 8423, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8324, End = 8424, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8325, End = 8425, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8326, End = 8426, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8327, End = 8427, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8328, End = 8428, Shape = (101, 25)
# 4/4 [==============================] - 0s 674us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8329, End = 8429, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8330, End = 8430, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8331, End = 8431, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8332, End = 8432, Shape = (101, 25)
# 4/4 [==============================] - 0s 1000us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8333, End = 8433, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8334, End = 8434, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8335, End = 8435, Shape = (101, 25)
# 4/4 [==============================] - 0s 1000us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8336, End = 8436, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8337, End = 8437, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8338, End = 8438, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8339, End = 8439, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8340, End = 8440, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8341, End = 8441, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8342, End = 8442, Shape = (101, 25)
# 4/4 [==============================] - 0s 1000us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8343, End = 8443, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8344, End = 8444, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8345, End = 8445, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8346, End = 8446, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8347, End = 8447, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8348, End = 8448, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8349, End = 8449, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8350, End = 8450, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8351, End = 8451, Shape = (101, 25)
# 4/4 [==============================] - 0s 999us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8352, End = 8452, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8353, End = 8453, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8354, End = 8454, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8355, End = 8455, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8356, End = 8456, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8357, End = 8457, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8358, End = 8458, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8359, End = 8459, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8360, End = 8460, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8361, End = 8461, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8362, End = 8462, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8363, End = 8463, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8364, End = 8464, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8365, End = 8465, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8366, End = 8466, Shape = (101, 25)
# 4/4 [==============================] - 0s 6ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8367, End = 8467, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8368, End = 8468, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8369, End = 8469, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8370, End = 8470, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8371, End = 8471, Shape = (101, 25)
# 4/4 [==============================] - 0s 1000us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8372, End = 8472, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8373, End = 8473, Shape = (101, 25)
# 4/4 [==============================] - 0s 1000us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8374, End = 8474, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8375, End = 8475, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8376, End = 8476, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8377, End = 8477, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8378, End = 8478, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8379, End = 8479, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8380, End = 8480, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8381, End = 8481, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8382, End = 8482, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8383, End = 8483, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8384, End = 8484, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8385, End = 8485, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8386, End = 8486, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8387, End = 8487, Shape = (101, 25)
# 4/4 [==============================] - 0s 6ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8388, End = 8488, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8389, End = 8489, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8390, End = 8490, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8391, End = 8491, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8392, End = 8492, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8393, End = 8493, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8394, End = 8494, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8395, End = 8495, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8396, End = 8496, Shape = (101, 25)
# 4/4 [==============================] - 0s 970us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8397, End = 8497, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8398, End = 8498, Shape = (101, 25)
# 4/4 [==============================] - 0s 1000us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8399, End = 8499, Shape = (101, 25)
# 4/4 [==============================] - 0s 2ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8400, End = 8500, Shape = (101, 25)
# 4/4 [==============================] - 0s 3ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8401, End = 8501, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8402, End = 8502, Shape = (101, 25)
# 4/4 [==============================] - 0s 538us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8403, End = 8503, Shape = (101, 25)
# 4/4 [==============================] - 0s 7ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8404, End = 8504, Shape = (101, 25)
# 4/4 [==============================] - 0s 1000us/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8405, End = 8505, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8406, End = 8506, Shape = (101, 25)
# 4/4 [==============================] - 0s 1ms/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8407, End = 8507, Shape = (101, 25)
# 4/4 [==============================] - 0s 0s/step
# Reconstructed shape: (101, 25)
# Processing slice: Start = 8408, End = 8508, Shape = (101, 25)
# 4/4 [==============================] - 0s 283us/step
# Reconstructed shape: (101, 25)
# F1 Score: 0.9403588168740908
# Precision: 0.9935109289617486
# Recall: 0.8926050935869899
# False Negatives: 350
# False Positives: 19
# True Negatives: 5231
# True Positives: 2909
# C:\Users\AXW0J9E\AppData\Local\Temp\ipykernel_16572\1647934281.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9403588168740908' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_predictions.loc[final_predictions['chan_id'] == stream, 'f1'] = f1
# C:\Users\AXW0J9E\AppData\Local\Temp\ipykernel_16572\1647934281.py:26: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9935109289617486' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_predictions.loc[final_predictions['chan_id'] == stream, 'precision'] = precision
# C:\Users\AXW0J9E\AppData\Local\Temp\ipykernel_16572\1647934281.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.8926050935869899' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_predictions.loc[final_predictions['chan_id'] == stream, 'recall'] = recall
# C:\Users\AXW0J9E\AppData\Local\Temp\ipykernel_16572\1647934281.py:50: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   final_predictions.loc[final_predictions['chan_id'] == stream, 'predicted_anomalies'] = str(predicted_anomalies)

# %%
telemetry = pd.DataFrame(test_df[0])
telemetry.columns = ['telemetry']
telemetry
# Out:
#       telemetry
# 0     -0.684211
# 1     -0.684211
# 2     -0.684211
# 3     -0.684211
# 4     -0.684211
# ...         ...
# 8504   0.578947
# 8505   0.578947
# 8506   0.578947
# 8507   0.578947
# 8508   0.578947
#
# [8509 rows x 1 columns]

# %%
final_frame = pd.concat([final_df, telemetry], axis=1)
final_frame
# Out:
#       anomaly_score  recon_losses  actual_anomaly  predicted_labels  telemetry
# 0          0.007983      0.000427             0.0                 0  -0.684211
# 1          0.007983      0.000427             0.0                 0  -0.684211
# 2          0.007983      0.000427             0.0                 0  -0.684211
# 3          0.007983      0.000427             0.0                 0  -0.684211
# 4          0.007983      0.000427             0.0                 0  -0.684211
# ...             ...           ...             ...               ...        ...
# 8504       0.476393      0.073483             1.0                 1   0.578947
# 8505       0.476393      0.073483             1.0                 1   0.578947
# 8506       0.476393      0.073483             1.0                 1   0.578947
# 8507       0.476393      0.073483             1.0                 1   0.578947
# 8508       0.476393      0.073483             1.0                 1   0.578947
#
# [8509 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# Sort the DataFrame by index
data = final_frame.sort_index()

# Split the data into two DataFrames based on the predicted_labels
data_red = data[data['predicted_labels'] == 1]
data_blue = data[data['predicted_labels'] == 0]

# Plot the red segments
plt.plot(data_red.index, data_red['telemetry'], 'r', label='Predicted Anomaly')

# Plot the blue segments
plt.plot(data_blue.index, data_blue['telemetry'], 'b', label='Predicted Normal')

# Add a title and labels to the plot
plt.title('Telemetry with Predicted Labels')
plt.xlabel('Index')
plt.ylabel('Telemetry Value')

# Display the legend
plt.legend()

# Display the plot
plt.show()
